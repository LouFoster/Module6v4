# %%
Deliverable 3. Create a Travel Itinerary Map
Create a folder called Vacation_Itinerary to store all the files for this deliverable.

Download the Vacation_Itinerary_starter_code.ipynb file into your Vacation_Itinerary folder and rename it Vacation_Itinerary.ipynb.

Make sure the initial dependencies and the Geoapify API key are imported.

From your Vacation_Search folder from Deliverable 2, import the WeatherPy_vacation.csv file as a DataFrame named vacation_df.

Use GeoViews to create a map that shows all the cities in the vacation_df DataFrame. Configure the map as follows:

The point's size should be the maximum temperature for the city

The point's color should be the city's name

Use the hover_cols parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.

From the map, choose four cities that a customer might want to visit. They should be close together and in the same country. Use the loc method to create separate DataFrames for each city on the travel route.

Hint: You will start and end the route in the same city, so the vacation_start and vacation_end DataFrames will be in the same city.

Use the Pandas concat function to merge the DataFrame from each city in the itinerary to create a new DataFrame named itinerary_df to store the itinerary details.

Use the Pandas copy function to create a new DataFrame named waypoints_df to store the longitude and latitude for each city in itinerary_df.

Hint: You'll use this DataFrame to create a map using GeoViews, so recall that the first column should be the longitude, and the second the latitude.

Use GeoViews to create a map that shows the four cities in the itinerary.

Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the waypoints parameter by using a for loop.

Hint: You can note that the mode parameter is set to drive, you can play around with other modes as it's shown in the "Travel modes" table in the Geoapify Routing API documentation.

Use the Geoapify Routing API to retrieve the route's directions for your itinerary.

From the JSON response, store the route's legs coordinates in a variable called legs.

Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude values into two Python lists named longitude and latitude.

Use the longitude and latitude Python lists to create a new DataFrame named route_df.

Use the GeoViews Path function to configure a line plot by using route_df. Set a custom color and width for the line that may contrast with the map.

Use the asterisk operator to display a composed plot that shows the itinerary's route over the map containing the cities.

Save your map to the Vacation_Itinerary folder as WeatherPy_travel_map.png.

Make sure the initial dependencies and the Geoapify API key are imported
# Dependencies and Setup
import geoviews as gv
import hvplot.pandas
import pandas as pd
import requests

import gmaps

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key
gmaps.configure(geoapify_key)
pip install gmaps 
Requirement already satisfied: gmaps in c:\users\lawua\anaconda3\lib\site-packages (0.9.0)
Requirement already satisfied: traitlets>=4.3.0 in c:\users\lawua\anaconda3\lib\site-packages (from gmaps) (5.1.1)
Requirement already satisfied: six in c:\users\lawua\anaconda3\lib\site-packages (from gmaps) (1.16.0)
Requirement already satisfied: geojson>=2.0.0 in c:\users\lawua\anaconda3\lib\site-packages (from gmaps) (3.0.1)
Requirement already satisfied: ipython>=5.3.0 in c:\users\lawua\anaconda3\lib\site-packages (from gmaps) (7.31.1)
Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\lawua\anaconda3\lib\site-packages (from gmaps) (7.6.5)
Requirement already satisfied: pickleshare in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
Requirement already satisfied: setuptools>=18.5 in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (63.4.1)
Requirement already satisfied: matplotlib-inline in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.6)
Requirement already satisfied: backcall in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
Requirement already satisfied: decorator in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
Requirement already satisfied: jedi>=0.16 in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
Requirement already satisfied: pygments in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
Requirement already satisfied: colorama in c:\users\lawua\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.5)
Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\lawua\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\lawua\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
Requirement already satisfied: nbformat>=4.2.0 in c:\users\lawua\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.5.0)
Requirement already satisfied: ipykernel>=4.5.1 in c:\users\lawua\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (6.15.2)
Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\lawua\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
Requirement already satisfied: pyzmq>=17 in c:\users\lawua\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (23.2.0)
Requirement already satisfied: psutil in c:\users\lawua\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.9.0)
Requirement already satisfied: nest-asyncio in c:\users\lawua\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\lawua\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (7.3.4)
Requirement already satisfied: tornado>=6.1 in c:\users\lawua\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
Requirement already satisfied: packaging in c:\users\lawua\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (21.3)
Requirement already satisfied: debugpy>=1.0 in c:\users\lawua\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lawua\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
Requirement already satisfied: fastjsonschema in c:\users\lawua\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.16.2)
Requirement already satisfied: jupyter_core in c:\users\lawua\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
Requirement already satisfied: jsonschema>=2.6 in c:\users\lawua\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.16.0)
Requirement already satisfied: wcwidth in c:\users\lawua\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
Requirement already satisfied: notebook>=4.4.1 in c:\users\lawua\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.12)
Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\lawua\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
Requirement already satisfied: attrs>=17.4.0 in c:\users\lawua\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
Requirement already satisfied: entrypoints in c:\users\lawua\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (0.4)
Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lawua\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
Requirement already satisfied: pywin32>=1.0 in c:\users\lawua\anaconda3\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (302)
Requirement already satisfied: argon2-cffi in c:\users\lawua\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
Requirement already satisfied: nbconvert>=5 in c:\users\lawua\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.4)
Requirement already satisfied: prometheus-client in c:\users\lawua\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.14.1)
Requirement already satisfied: terminado>=0.8.3 in c:\users\lawua\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\lawua\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
Requirement already satisfied: jinja2 in c:\users\lawua\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lawua\anaconda3\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (3.0.9)
Requirement already satisfied: beautifulsoup4 in c:\users\lawua\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
Requirement already satisfied: bleach in c:\users\lawua\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\lawua\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lawua\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lawua\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
Requirement already satisfied: testpath in c:\users\lawua\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
Requirement already satisfied: jupyterlab-pygments in c:\users\lawua\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
Requirement already satisfied: defusedxml in c:\users\lawua\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lawua\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
Requirement already satisfied: pywinpty>=1.1.0 in c:\users\lawua\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.2)
Requirement already satisfied: argon2-cffi-bindings in c:\users\lawua\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
Requirement already satisfied: cffi>=1.0.1 in c:\users\lawua\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.1)
Requirement already satisfied: soupsieve>1.2 in c:\users\lawua\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
Requirement already satisfied: webencodings in c:\users\lawua\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
Requirement already satisfied: pycparser in c:\users\lawua\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
Note: you may need to restart the kernel to use updated packages.
From your Vacation_Search folder from Deliverable 2, import the WeatherPy_vacation.csv file as a DataFrame named vacation_df
# Read the WeatherPy_vacation.csv into a DataFrame
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head()
# Display sample data
# YOUR CODE HERE
City_ID	City	Country	Max Temp	Current Description	Lat	Lng	Hotel Name
0	1	Rikitea	PF	79.72	broken clouds	-23.1203	-134.9692	Chez Bianca & Benoit
1	3	Sambava	MG	76.44	light rain	-14.2667	50.1667	Royal Sava Hôtel
2	4	Bandarbeyla	SO	80.65	few clouds	9.4942	50.8122	No hotel found
3	5	Kapaa	US	80.92	light rain	22.0752	-159.3190	Pono Kai Resort
4	6	Ciudad Valles	MX	70.21	clear sky	21.9833	-99.0167	Hotel Riviera
#itinerary_df = ["Name"] = ""
# Create DataFrame called to store hotel names along with city, country, max temp, and coordinates.
#itinerary_df = [["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
 
 
Figure(layout=FigureLayout(height='420px'))
---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
~\AppData\Local\Temp\ipykernel_13816\518190151.py in <module>
----> 1 Figure(layout=FigureLayout(height='420px'))

NameError: name 'Figure' is not defined
# 5. From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Havre"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Havre"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Saint-Dizier"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Saint-Francois"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Semme"] 
#Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
Use GeoViews to create a map that shows all the cities in the vacation_df DataFrame. Configure the map as follows:
The point's size should be the maximum temperature for the city

The point's color should be the city's name

Use the hover_cols parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.

# Configure the map plot
map_plot = # YOUR CODE HERE

# Display the map
# YOUR CODE HERE
From the map, choose four cities that a customer might want to visit. They should be close together and in the same country. Use the loc method to create separate DataFrames for each city on the travel route.
# Create DataFrames for each city by filtering the 'vacation_df' using the loc method
vacation_start = # YOUR CODE HERE
vacation_end = # YOUR CODE HERE
vacation_stop1 = # YOUR CODE HERE
vacation_stop2 = # YOUR CODE HERE
vacation_stop3 = # YOUR CODE HERE
Use the Pandas concat function to merge the DataFrame from each city in the itinerary to create a new DataFrame named itinerary_df to store the itinerary details
# Use the Pandas concat function to create a new DataFrame to store the itinerary details.
itinerary_df = # YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
Use the Pandas copy function to create a new DataFrame named waypoints_df to store the longitude and latitude for each city in itinerary_df
# Create a Pandas DataFrame to store the latitude and longitude for each city in the itineray
waypoints_df = # YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
Use GeoViews to create map that shows the four cities in the itinerary
# Configure the map plot by using the itineraty_df
waypoints_map = # YOUR CODE HERE
# Display the route_map
# YOUR CODE HERE
Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the waypoints parameter by using a for loop
# Set parameters to trace the route
radius = 5000
params = {
    "mode":"drive",
    "apiKey": geoapify_key,
}
# Set an empty waypoints String variable
waypoints = ""

# Iterate through the route_df DataFrame to define the waypoints
for index, row in waypoints_df.iterrows():
    waypoints = waypoints + str(row["Lat"]) + "," + str(row["Lng"]) + "|"

# Delete the last character from the string
waypoints = waypoints[:-1]

# Add the waypoints to the params dictionary
params["waypoints"] = waypoints

# Display the params dictionary
params
Use the Geoapify Routing API to retrieve the route's directions for your itinerary
# Set up the base URL for the Geoapify Places API.
base_url = "https://api.geoapify.com/v1/routing"

# Make request and retrieve the JSON data by using the params dictionaty
route_response = # YOUR CODE HERE

# Convert the API response to JSON format
route_response = # YOUR CODE HERE
From the JSON response, store the route's legs coordinates in a variable called legs
# Fetch the route's legs coordinates from the JSON reponse
legs = # YOUR CODE HERE
Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude value into two Python lists names longitude and latitude
# Create and empty list to store the longitude of each step
# YOUR CODE HERE

# Create and empty list to store the latitude of step
# YOUR CODE HERE

# Loop through the legs coordinates to fetch the latitude and longitude for each step
# YOUR CODE HERE
Use the longitude and latitude Python lists to create a new DataFrame named route_df
# Create an empty DataFrame to store the steps' coordinates
route_df = # YOUR CODE HERE

# Add the steps' longitude and latitude from each step as columns to the DataFrame
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
Use the GeoViews Path function to configure a line plot by using route_df. Set a custom color and width for the line that may contrast with the map
# Configure the route path by using the GeoViews' Path function
route_path = # YOUR CODE HERE
# Display a composed plot by using the route_map and route_path objects
# YOUR CODE HERE
